# %% [markdown]
# # RNN,  LSTM vizual plot

# %%
# !pip install Keras
# !pip install tensorflow
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from scipy.fftpack import fft
from scipy import signal
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
import io
import pandas as pd
import numpy as np
import matplotlib  as mpl
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from sklearn.preprocessing import MinMaxScaler
# Out:
# Requirement already satisfied: Keras in c:\users\20522\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: scipy>=0.14 in c:\users\20522\anaconda3\lib\site-packages (from Keras) (1.4.1)
# Requirement already satisfied: pyyaml in c:\users\20522\anaconda3\lib\site-packages (from Keras) (5.3)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\20522\anaconda3\lib\site-packages (from Keras) (1.19.5)
# Requirement already satisfied: h5py in c:\users\20522\anaconda3\lib\site-packages (from Keras) (2.10.0)
# Requirement already satisfied: six in c:\users\20522\anaconda3\lib\site-packages (from h5py->Keras) (1.15.0)
# Requirement already satisfied: tensorflow in c:\users\20522\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six~=1.15.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: wheel~=0.35 in c:\users\20522\anaconda3\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (2.22.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\20522\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\20522\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\20522\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (3.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\20522\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (0.4.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (45.2.0.post20200210)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\20522\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\20522\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\20522\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\20522\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\20522\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2019.11.28)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\20522\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\20522\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\20522\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\20522\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow) (1.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\20522\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\20522\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\20522\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (2.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\20522\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)

# %%
# %matplotlib inline
dfx=pd.read_csv('data_zero.csv')
calculation_speed = 100
dfx[::calculation_speed]
# Out:
#             miliseka  P_147_P0  P_147_P1  P_147_P1_L  P_147_P1_W  P_157_P0  \
# 0       1.313696e+12  0.000000  0.000000    0.000000    0.000000  0.000000
# 100     1.313696e+12  0.005245  0.009537   -0.003815    0.011448 -0.008013
# 200     1.313696e+12  0.003815 -0.017170    0.000000    0.024799 -0.004580
# 300     1.313696e+12  0.000477 -0.030521   -0.007629   -0.051498 -0.029757
# 400     1.313696e+12  0.000000  0.015259   -0.019073    0.007633  0.009155
# ...              ...       ...       ...         ...         ...       ...
# 119500  1.313697e+12  0.015259 -0.038151   -0.040054   -0.011444 -0.003435
# 119600  1.313697e+12  0.015736 -0.028614   -0.040054   -0.032425 -0.008013
# 119700  1.313697e+12  0.017643 -0.024799   -0.043869   -0.009537 -0.014879
# 119800  1.313697e+12  0.020028 -0.028614   -0.026703   -0.032425 -0.024035
# 119900  1.313697e+12  0.015259 -0.041965   -0.036240   -0.026703 -0.010302
#
#         P_157_P0_L  P_157_P1  P_158_P0_FM  P_180_P0  ...  P_217_P0  \
# 0         0.000000  0.000000     0.000000  0.000000  ...  0.000000
# 100      -0.001907 -0.005722    -0.034332  0.003433  ... -0.018311
# 200      -0.005722 -0.005722    -0.043869 -0.003433  ... -0.018311
# 300      -0.013351 -0.027466    -0.036240 -0.027468  ... -0.004578
# 400       0.000000  0.012589    -0.064850  0.017166  ... -0.003433
# ...            ...       ...          ...       ...  ...       ...
# 119500   -0.013351 -0.003433    -0.036240 -0.029757  ... -0.049210
# 119600   -0.022888 -0.011444    -0.043869 -0.025179  ... -0.058365
# 119700   -0.020981 -0.014877    -0.045776 -0.006866  ... -0.042343
# 119800   -0.026703 -0.024033    -0.047684 -0.019457  ... -0.048065
# 119900   -0.020981 -0.009155    -0.057220 -0.017168  ... -0.059509
#
#         P_237_P0_FM  P_253_P0  P_272_P0  P_281_P0  P_292_P0  P_312_P0  \
# 0          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 100        0.011446 -0.006866  0.010300  0.004578 -0.010300  0.017168
# 200       -0.005722 -0.002289  0.000000  0.001144 -0.016022  0.030901
# 300        0.020983 -0.003433  0.008011  0.004578 -0.012589  0.011446
# 400        0.007631  0.006866  0.002289 -0.005722 -0.005722  0.032045
# ...             ...       ...       ...       ...       ...       ...
# 119500    -0.017166 -0.065231 -0.067522 -0.068665 -0.101854 -0.097275
# 119600    -0.026703 -0.062943 -0.068666 -0.081253 -0.089266 -0.081253
# 119700    -0.024796 -0.073242 -0.072100 -0.078964 -0.089266 -0.078964
# 119800    -0.038147 -0.064087 -0.069811 -0.074387 -0.109865 -0.107574
# 119900    -0.022888 -0.072098 -0.074389 -0.082397 -0.094988 -0.094986
#
#         P_335_P0  P_354_P0  P_375_P0
# 0       0.000000  0.000000  0.000000
# 100    -0.028229 -0.022125  0.048829
# 200    -0.028229 -0.022888  0.000763
# 300    -0.000763 -0.022888 -0.016785
# 400     0.038148 -0.019836 -0.028229
# ...          ...       ...       ...
# 119500 -0.163272 -0.180820 -0.220493
# 119600 -0.158694 -0.192264 -0.215915
# 119700 -0.130465 -0.178531 -0.219730
# 119800 -0.135042 -0.186923 -0.232700
# 119900 -0.144197 -0.160220 -0.179294
#
# [1200 rows x 24 columns]

# %%
# **Why is do we have 3 values as inputs?**

# We will see latter that RNNs, LTSMs require 3D input for the X values. This is often very confusing for beginners and people who return back to the field after a break (make sure you remember this, because even if you are an employeed data scientist you might not work with RNNs and forget this information, which is fundamental to understanding of RNNs). What are those 3 dimensions:

# - **Samples / how many sequences**. One sequence is one sample. A batch is comprised of one or more samples (batch size not specified).
# - **Time Steps / how many values in each sample**. One time step is one point of observation in the sample.
# - **Features / collumn count**. One feature is one observation at a time step. This is essentially how many values at each time step you have.

# Say we want to feed this into our network:

# %%
def taking_of_nan_values_DF(df):
    print("taking_of_nan_values_DF(df)")
    # interpolation
    df = df.interpolate(method='linear', limit_direction='forward', axis=0)
    # taking of nullmi
    df = df.fillna(method='ffill')
    df = df.fillna(method='bfill')
    return df

# %%
df = pd.DataFrame(dfx[::calculation_speed])
df = taking_of_nan_values_DF(pd.DataFrame(df))
df
# Out:
# taking_of_nan_values_DF(df)
#             miliseka  P_147_P0  P_147_P1  P_147_P1_L  P_147_P1_W  P_157_P0  \
# 0       1.313696e+12  0.000000  0.000000    0.000000    0.000000  0.000000
# 100     1.313696e+12  0.005245  0.009537   -0.003815    0.011448 -0.008013
# 200     1.313696e+12  0.003815 -0.017170    0.000000    0.024799 -0.004580
# 300     1.313696e+12  0.000477 -0.030521   -0.007629   -0.051498 -0.029757
# 400     1.313696e+12  0.000000  0.015259   -0.019073    0.007633  0.009155
# ...              ...       ...       ...         ...         ...       ...
# 119500  1.313697e+12  0.015259 -0.038151   -0.040054   -0.011444 -0.003435
# 119600  1.313697e+12  0.015736 -0.028614   -0.040054   -0.032425 -0.008013
# 119700  1.313697e+12  0.017643 -0.024799   -0.043869   -0.009537 -0.014879
# 119800  1.313697e+12  0.020028 -0.028614   -0.026703   -0.032425 -0.024035
# 119900  1.313697e+12  0.015259 -0.041965   -0.036240   -0.026703 -0.010302
#
#         P_157_P0_L  P_157_P1  P_158_P0_FM  P_180_P0  ...  P_217_P0  \
# 0         0.000000  0.000000     0.000000  0.000000  ...  0.000000
# 100      -0.001907 -0.005722    -0.034332  0.003433  ... -0.018311
# 200      -0.005722 -0.005722    -0.043869 -0.003433  ... -0.018311
# 300      -0.013351 -0.027466    -0.036240 -0.027468  ... -0.004578
# 400       0.000000  0.012589    -0.064850  0.017166  ... -0.003433
# ...            ...       ...          ...       ...  ...       ...
# 119500   -0.013351 -0.003433    -0.036240 -0.029757  ... -0.049210
# 119600   -0.022888 -0.011444    -0.043869 -0.025179  ... -0.058365
# 119700   -0.020981 -0.014877    -0.045776 -0.006866  ... -0.042343
# 119800   -0.026703 -0.024033    -0.047684 -0.019457  ... -0.048065
# 119900   -0.020981 -0.009155    -0.057220 -0.017168  ... -0.059509
#
#         P_237_P0_FM  P_253_P0  P_272_P0  P_281_P0  P_292_P0  P_312_P0  \
# 0          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 100        0.011446 -0.006866  0.010300  0.004578 -0.010300  0.017168
# 200       -0.005722 -0.002289  0.000000  0.001144 -0.016022  0.030901
# 300        0.020983 -0.003433  0.008011  0.004578 -0.012589  0.011446
# 400        0.007631  0.006866  0.002289 -0.005722 -0.005722  0.032045
# ...             ...       ...       ...       ...       ...       ...
# 119500    -0.017166 -0.065231 -0.067522 -0.068665 -0.101854 -0.097275
# 119600    -0.026703 -0.062943 -0.068666 -0.081253 -0.089266 -0.081253
# 119700    -0.024796 -0.073242 -0.072100 -0.078964 -0.089266 -0.078964
# 119800    -0.038147 -0.064087 -0.069811 -0.074387 -0.109865 -0.107574
# 119900    -0.022888 -0.072098 -0.074389 -0.082397 -0.094988 -0.094986
#
#         P_335_P0  P_354_P0  P_375_P0
# 0       0.000000  0.000000  0.000000
# 100    -0.028229 -0.022125  0.048829
# 200    -0.028229 -0.022888  0.000763
# 300    -0.000763 -0.022888 -0.016785
# 400     0.038148 -0.019836 -0.028229
# ...          ...       ...       ...
# 119500 -0.163272 -0.180820 -0.220493
# 119600 -0.158694 -0.192264 -0.215915
# 119700 -0.130465 -0.178531 -0.219730
# 119800 -0.135042 -0.186923 -0.232700
# 119900 -0.144197 -0.160220 -0.179294
#
# [1200 rows x 24 columns]

# %%
def plot_learning_curves(loss):
    print("plot_learning_curves(loss)")
    plt.figure(figsize=(14,5))
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    # plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %%
def RNN2(new_dataset, valid_data, interval_to_train, column, scaler, lstm_model, parameter):      
    # construct the dataset for prediction
    inputs_data=new_dataset[len(new_dataset)-len(valid_data)-parameter:].values
    inputs_data=inputs_data.reshape(-1,1)
    inputs_data=scaler.transform(inputs_data)
    X_test=[]
    for i in range(parameter,inputs_data.shape[0]):
        X_test.append(inputs_data[i-parameter:i,0])
    X_test=np.array(X_test)
    X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

    predicted_closing_price=lstm_model.predict(X_test)
#     print(predicted_closing_price)
    predicted_closing_price=scaler.inverse_transform(predicted_closing_price)
#     print(predicted_closing_price)

    train_data=new_dataset[:interval_to_train]
    valid_data=new_dataset[interval_to_train:]
    valid_data = valid_data.assign(Predictions=predicted_closing_price)
    plt.figure(figsize=(14,5))
    plt.plot(new_dataset[str(column)])    
    plt.title('RNN LSTM ' + str(column), size=12)
    plt.plot(valid_data.index, predicted_closing_price)
    plt.show()
    # Calculate the MSE for predictions
    from sklearn.metrics import mean_squared_error
    mean_squared_error(valid_data[str(column)],predicted_closing_price) 
   # Increase the epoch count and retrain the network, see if MSE improves

# %%
def RNN(df):
    columns = df.columns
    print("Starting RNN(df)")
    df[df.columns[0]] = pd.to_datetime(df[df.columns[0]], unit='ms')
    import datetime    
    rows = len(df)
    # parameters
    parameter = 10
    number_of_epochs = 10
    number_of_batch_size = 10
    interval_to_train = int(rows/2)

    columns = df.columns
    for column in columns:
        if column != df.columns[0]:

            print(column)
            df['Date'] = df[df.columns[0]]
            # Timestamp('2017-03-22 15:16:45.433502912')
            df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
            df.index=df['Date']
            
            data=df.sort_index(ascending=True,axis=0)
            new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date',str(column)])

            for i in range(0,len(data)):
                new_dataset["Date"][i]=data['Date'][i]
                new_dataset[str(column)][i]=data[str(column)][i]

            train_data = new_dataset[0:interval_to_train]
            valid_data = new_dataset[interval_to_train:]

            new_dataset.index=new_dataset.Date
            new_dataset.drop("Date",axis=1,inplace=True)

            new_dataset.tail(5)

            scaler=MinMaxScaler(feature_range=(0,1))
            scaled_data=scaler.fit_transform(new_dataset)

            # construct the sequences: we will try to predict y
            # ... based on last parameter values of x
            x_train_data, y_train_data=[],[]
            for i in range(parameter,len(train_data)):
                x_train_data.append(scaled_data[i-parameter:i,0])
                y_train_data.append(scaled_data[i,0])

            # convert to numpy
            x_train_data, y_train_data = np.array(x_train_data), np.array(y_train_data)
            print(x_train_data.shape)

            # reshape it to 3D
            x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

            # to see how the shape changes we can again print it out
            lstm_model=Sequential()
            lstm_model.add(LSTM(units=50, return_sequences=True,input_shape=(x_train_data.shape[1],1)))
            lstm_model.add(LSTM(units=50))
            lstm_model.add(Dense(1))
            lstm_model.compile(loss='mean_squared_error',optimizer='adam')
            
            history = lstm_model.fit(x_train_data,y_train_data, epochs=number_of_epochs, batch_size=number_of_batch_size,verbose=1)
            
            plot_learning_curves(history.history["loss"])
            plt.show()
            
            RNN2(new_dataset, valid_data, interval_to_train, column, scaler, lstm_model, parameter)
          
           # Increase the epoch count and retrain the network, see if MSE improves

# %%
RNN(df)
# Out:
# Starting RNN(df)
# P_147_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 2s 4ms/step - loss: 0.0408
# Epoch 2/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 3/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 4/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 5/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 6/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 7/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 8/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0082
# Epoch 9/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 10/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0089
# plot_learning_curves(loss)
# P_147_P1
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 4s 6ms/step - loss: 0.0635
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0169
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0201
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0160
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0169
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0158
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0173
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0154
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0183
# plot_learning_curves(loss)
# P_147_P1_L
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.0852
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0147
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0155
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0159
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0172
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0162
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0161
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0145
# plot_learning_curves(loss)
# P_147_P1_W
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 7ms/step - loss: 0.0880
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0211
# Epoch 4/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0243
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0229
# Epoch 6/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0208
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0215
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0205
# Epoch 10/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0211
# plot_learning_curves(loss)
# P_157_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.0899
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0158
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0182
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0171
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0149
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0163
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0165
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0178
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0163
# plot_learning_curves(loss)
# P_157_P0_L
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.0940
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0183
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0181
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0173
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0175
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0179
# plot_learning_curves(loss)
# P_157_P1
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 2s 4ms/step - loss: 0.1039
# Epoch 2/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0175
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0155
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0199
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0179
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0184
# Epoch 7/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0185
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0172
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0181
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0180
# plot_learning_curves(loss)
# P_158_P0_FM
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.1216
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0164
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0162
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0159
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0149
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0163
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0151
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0161A: 0s - loss: 0
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0148
# plot_learning_curves(loss)
# P_180_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.1144
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0207
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0189
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0185
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0189
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0199
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0183
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0198
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0190
# plot_learning_curves(loss)
# P_199_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.0915
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0215
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0252
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0219
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0229
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0215
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0208
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0204
# Epoch 9/10
# 59/59 [==============================] - ETA: 0s - loss: 0.023 - 0s 8ms/step - loss: 0.0236
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0211A: 0s - loss:
# plot_learning_curves(loss)
# P_208_P0_FM
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.1097
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0175
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0184
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0165
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0184
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0164
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0169
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0176
# plot_learning_curves(loss)
# P_209_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.1316
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0161
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0151
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0140
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0151
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0155
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0154
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0153
# plot_learning_curves(loss)
# P_209_P1
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 5ms/step - loss: 0.1127
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0163
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0170
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0173
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0161
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0145
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0162
# plot_learning_curves(loss)
# P_217_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 2s 5ms/step - loss: 0.1209
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0135
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0154
# Epoch 4/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0135
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0129
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0132
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0131
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0124
# Epoch 9/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0133
# Epoch 10/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0137
# plot_learning_curves(loss)
# P_237_P0_FM
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 4s 7ms/step - loss: 0.1572
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0111
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0110
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0121
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0117
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0112
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0125
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0118
# plot_learning_curves(loss)
# P_253_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 7ms/step - loss: 0.1610
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0064
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0059
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0068
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0064A: 0s - loss:
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0060
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0063
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0058
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0064
# plot_learning_curves(loss)
# P_272_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 4s 6ms/step - loss: 0.1380
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0053
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0052
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0056
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0054
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0058
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0053
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0055
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0060
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0054
# plot_learning_curves(loss)
# P_281_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.1251
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0043
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0040
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0045
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0046
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0042
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0039
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0037
# plot_learning_curves(loss)
# P_292_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 4s 8ms/step - loss: 0.1678
# Epoch 2/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0038
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0041
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0037A: 0s - loss: 0
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0039
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 7/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0044
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0051
# plot_learning_curves(loss)
# P_312_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.1960
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0044
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0050
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0049
# Epoch 7/10
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0045
# Epoch 8/10
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0050
# Epoch 9/10
# 59/59 [==============================] - 0s 8ms/step - loss: 0.0047
# Epoch 10/10
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0044
# plot_learning_curves(loss)
# P_335_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.0981
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0048
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0063
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0061
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0059
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0059
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0065
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0051
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0053
# plot_learning_curves(loss)
# P_354_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 5ms/step - loss: 0.1080
# Epoch 2/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0056
# Epoch 3/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 4/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 5/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0062
# Epoch 6/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0061
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0064
# Epoch 8/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0063
# Epoch 9/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0062
# Epoch 10/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0064
# plot_learning_curves(loss)
# P_375_P0
# (590, 10)
# Epoch 1/10
# 59/59 [==============================] - 3s 6ms/step - loss: 0.0785
# Epoch 2/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 3/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 4/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0072
# Epoch 5/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 6/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0078
# Epoch 7/10
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 8/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0066
# Epoch 9/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0070
# Epoch 10/10
# 59/59 [==============================] - 0s 7ms/step - loss: 0.0067
# plot_learning_curves(loss)
